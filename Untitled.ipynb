# %%
x = 5
y="Joha"
print(x)
print(y)
# Out:
# 5
# Joha

# %%
x = 4
x="Sally"
x = 8
print(x)
# Out:
# 8

# %%
x = str(3)
y=int(3)
z=float(3)
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
x = 5
y = "johon"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [raw]
# a = 4
# A="Sally"
# print(a)
# print(A)

# %%
x,y,z="Orange","banana","cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# banana
# cherry

# %%
x=y=z="Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
fruits=["apple","banana","cherry"]
x,y,z=fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
z="Python"
y="is"
z="awesome"
print(x,y,z)
# Out:
# apple is awesome

# %%
x=5
print(type(x))
print(x)
# Out:
# <class 'int'>
# 5

# %%
x=1
y=2.8
z=1j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x=1
y=35656222554887711
z=-3255522
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x=1.10
y=1.0
z=-35.59
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x=3+5j
y=5j
z=-5j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
x=1
y=2.8
z=1j
a=float(x)
b=int(y)
c=complex(x)
print(a)
print(b)
print(c)
# Out:
# 1.0
# 2
# (1+0j)

# %%
x=int(1)
y=int(2.8)
z=int("3")
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
x=float(1)
y=float(2.8)
z=float("3")
w=float("4.2")
print(x)
print(y)
print(z)
print(w)
# Out:
# 1.0
# 2.8
# 3.0
# 4.2

# %%
x=str("s1")
y=str(2)
z=str(3.0)
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0

# %%
a="Hello"
print(a)
# Out:
# Hello

# %%
a="Hello","world!"
print(a[1])
# Out:
# world!

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
a="Hello,World!"
print(len(a))
# Out:
# 12

# %%
txt="The best things in life are free!"
print("free" in txt)
# Out:
# True

# %%
charge=int(input("Enter your bettery level:"))
  if charge>=90:
            print("youre bettery is full")
  elif charge>=50: 
            print("Bettery is okay")
  else:
       print("Bettery low")
# Out:
#   Cell In[8], line 2
#     if charge>=90:
#     ^
# IndentationError: unexpected indent

# %%
b=input("Enter the value:")
a=5
for i in range(a,0,-1):
    print(b *i)
# Out:
# Enter the value: 6
# 66666
# 6666
# 666
# 66
# 6

# %%
b= input("Enter the value:")
a=5
for i in range(a,0,+1):
   print(b *i)
for j in range(a,0,+1):
    print(b *i,j)

# %%
a=int(input("Enter the vaiue:"))
for i in range(1,a+1,2):
    print(i)
# Out:
# Enter the vaiue: 10
# 1
# 3
# 5
# 7
# 9

# %%
singnal=str(input("enter the traffic singnal"))
if singnal=="Red" :
    print("STOP")
elif singnal=="Yellow" :
    print("READY")
elif singnal=="Green" :
     print("GO")
else:
    print("invalid input")
# Out:
# enter the traffic singnal Red
# STOP
